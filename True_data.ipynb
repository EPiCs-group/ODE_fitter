# %% [markdown]
# This is a document for refererence which values the algorithms are trying to find.
# All 6 constant systems are based of these values.

# %%
import pandas as pd
dic = {'Rates' : ['k1','k2f','k2b','k3','k4','k5'],
    'T=323': [0.00589749, 0.00852319, 0.00216736, 0.05455227, 0.01977726, 0.00467962], 
    'T=363':[0.01209668, 0.01517495, 0.00426081, 0.08974876, 0.03289181, 0.01269032],
        'T=393':[0.0188359,  0.02165481, 0.0064632,  0.12198501, 0.0450056,  0.02347147],
      'Activation energies':[-17507.67079081, -14058.09983295, -16473.03587668, -12132.82763899, -12396.90042988, -24312.24532045],
      'Arrhenius pre-factors': [4, 1.6, 1, 5, 2, 40]}
pd.DataFrame(dic)
# Out:
#   Rates     T=323     T=363     T=393  Activation energies  \
# 0    k1  0.005897  0.012097  0.018836        -17507.670791
# 1   k2f  0.008523  0.015175  0.021655        -14058.099833
# 2   k2b  0.002167  0.004261  0.006463        -16473.035877
# 3    k3  0.054552  0.089749  0.121985        -12132.827639
# 4    k4  0.019777  0.032892  0.045006        -12396.900430
# 5    k5  0.004680  0.012690  0.023471        -24312.245320
#
#    Arrhenius pre-factors
# 0                    4.0
# 1                    1.6
# 2                    1.0
# 3                    5.0
# 4                    2.0
# 5                   40.0
