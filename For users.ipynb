# %%
#please not that the initial conditions of reactions need to be tuned so that rate constants don't exceed 1, this overloads the dfferential solver
#needed imports
import Usable_program_real as prg
import matplotlib.pyplot as plt
import numpy as np

# %%
timespan = [0, 1, 3, 5, 7, 9, 11, 13, 15, 19, 23, 27, 31, 40, 50, 60, 90, 120, 150, 180, 240, 300, 360, 440, 530, 620, 810, 900, 955, 1246]

# %%
# simple example of running systems of ODE's
ks = [0.01209668296564242] #define all rate constants in a list
concs = [1,0,0] #define initial conditions

reactions = {1:"ks[0]*concs[0]"} #define the reactions that can happen in a dictionary, write them down as strings, this is more modular
matrix = {"dEdt": {1:-1},"dA1dt": {1:1},"dA2dt": {1:1}} #define for each species which reactions apply, and with which stoichiometric constant, so{"dXdt": {reaction:-stoichiometric_constant}, etc.}
#if more reactions apply it would look like {"dEdt": {1:-1, 2:1}}
#for structuring of more complex system look at test_6 at the bottom

# %%
#make an ODE system out of it
test = prg.ODE_systems(reactions,matrix,ks,concs)

# %%
# have the program run your ODE to see how it behaves
prof = test.run_ODEs()
test.get_matrices()#how the info in the system looks
# Out:
#  reaction matrix: {'dEdt': {1: -1}, 'dA1dt': {1: 1}, 'dA2dt': {1: 1}}
#  rate constants: [0.01209668296564242]
#  reactions: {1: 'ks[0]*concs[0]'}
#  initial conditions: [1, 0, 0]
# [[{'dEdt': {1: -1}, 'dA1dt': {1: 1}, 'dA2dt': {1: 1}}, [0.01209668296564242], {1: 'ks[0]*concs[0]'}, [1, 0, 0]]]

# %%
# now for making theoretical data if there is no real data
#syntax is derived from basic scipy integrating syntax
def diff_data(t, init, rate_const): #function that recieves data needs to take these parameters. t denotes the range over which it is executed, init denotes initial conditions, rate_const denotes the rate constants used
    CE, CA1, CA2, CtE,Cprecat, Ccat, Ccatdead = init # though the system is simple it does have 7 initial conditions, this is due to the fact that we want to fit it with a more complex system that includes everything later
    k1= rate_const[0] #get out the individual rate constants from rate_const
    dEdt = -k1*CE #write out the reactions
    dA1dt = k1*CE
    dA2dt = k1*CE
    return dEdt, dA1dt, dA2dt,0,0,0,0 #amount of outputs needs to be equal to the amount of initial conditions, add zeros if the amount of changing parameters is less

# %%
#now that we have a system lets make data out of it
#the make data function looks like this make_data (system,timespan ,Ts,inits,ks,kin_params = None,var_noise = 0, stat_noise = 0)
#system is the differential system the data is made for, timespan is the time measured over, Ts is all temperatures you want simulated
#inits is all the inits you want simulated, ks is the value of the rate constants, var_noise and stat_noise allow you to add noise to data
# kin_params is for when simulations are done at different temperatures, because the rate constants change of course. the structure is [Temperature_the_base_rate_constant_is_defined_at, [Eact1,Eact2,etc...]]
data = prg.make_data(diff_data,timespan ,[300,400],[[1,0,0,0,1,0,0],[2,0,0,0,2,0,0]],ks,var_noise = 0.05, stat_noise = 0.01,kin_params = [300,[7573]])
#out differential had 3 significant parameters, so the lenth of the output matrix is 3
print(len(data[0]['y']))
#there are now 4 runs since we defined 2 initial conditions and 2 temperatures
plt.figure() #first run is first initial condition, first temperature
plt.plot(data[0]['t'],data[0]['y'][0])
plt.plot(data[0]['t'],data[0]['y'][1])
plt.plot(data[0]['t'],data[0]['y'][2])

plt.figure() #second run is first initial condition, second temperature
plt.plot(data[1]['t'],data[1]['y'][0])
plt.plot(data[1]['t'],data[1]['y'][1])
plt.plot(data[1]['t'],data[1]['y'][2])

plt.figure() #third run is second initial condition, first temperature
plt.plot(data[2]['t'],data[2]['y'][0])
plt.plot(data[2]['t'],data[2]['y'][1])
plt.plot(data[2]['t'],data[2]['y'][2])

plt.figure() #fourth run is second initial condition, second temperature
plt.plot(data[3]['t'],data[2]['y'][0])
plt.plot(data[3]['t'],data[2]['y'][1])
plt.plot(data[3]['t'],data[2]['y'][2])
# Out:
# 3

# %%
# #this cell is to shwo how you make custom data, if there is real data it can be implemeted in this format
# t = [0,1,2,3,4,5] #each run had a time
# y = [np.array([1,0.7,0.55,0.45,0.35,0.3]),
#      np.array([0,0.4,0.55,0.65,0.75,0.8])] #it has the concentration steps at each time, (can be list of lists or list of arrays)
# y = [[1,0.7,0.55,0.45,0.35,0.3],
#     [0,0.4,0.55,0.65,0.75,0.8]] #data as list of lists
# T = 300 #temperature measured at
# init = [1, 0, 0, 0, 1, 0, 0] #initial conditions for the measurement

# #runs can be done in parallel, here we'll do 2
# t2 = [0,1,2,3,4,5]
# y2 = [np.array([2,1.2,0.95,0.85,0.75,0.65]),
#      np.array([0,1,1.2,1.4,1.5,1.6])]
# T2 = 400
# init2 = [2, 0, 0, 0, 1, 0, 0]

# data = [{'t':t, 'y':y, 'T':T, 'init':init},{'t':t2, 'y':y2, 'T':T2, 'init':init2}] #this is how to combine all the data in one dictionary

# %%
# remember the ODE system we made, lets fit the data to that system
test_fit_1 = prg.fit_data(data, test.get_matrices()) #we make a fitting set with the fit_data class, ODE systems need to be converted to the right reaction matrix with the get_matrices() function
test_fit_1.fit_full(0) #a full fit means we find all rate constants and then combine them into guesses for the kinetic parameters. We then also guess the kinetic parameters
#the syntax of the function is fit_full(system_num, iterations = 1000, iterations_full = 1000)
# system_num denotes which system we fit, if there is only one this is 0, we'll see later how we can play with convenietly fitting mutiple systems.
#number of iterations can also be changed if desired
# Out:
#  reaction matrix: {'dEdt': {1: -1}, 'dA1dt': {1: 1}, 'dA2dt': {1: 1}}
#  rate constants: [0.01209668296564242]
#  reactions: {1: 'ks[0]*concs[0]'}
#  initial conditions: [1, 0, 0]
# -3.791925544256812
# -3.791925544256812
# -3.791925544256812
# -3.791925417151827
# 0.6159206056478841
# 0.6159205961083514
# -4.368265749996032
# 1.8941193223962087
# 1.894119326838982
# 0.8132132079301974
# 1.9077322439820497
# 1.9077322424142995
# 1.8937536402417803
# 1.9111832845972858
# 1.9111832845508483
# 1.907976809578154
# 1.9111684648270548
# 1.9111858718131178
# 1.9111858718130765
# 1.911183292477411
# 1.9111858464987983
# 1.9111858718131178
# 1.9111858718131178
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 19
#     # data points      = 6
#     # variables        = 1
#     chi-square         = 100.310406
#     reduced chi-square = 20.0620812
#     Akaike info crit   = 18.8990598
#     Bayesian info crit = 18.6908193
# [[Variables]]
#     k0:  0.30014428 +/- 125689.489 (41876356.03%) (init = 0.01)
# -4.159750294716408
# -4.159750294716408
# -4.159750294716408
# -4.15975016919081
# 0.9496108301242706
# 0.9496108232076137
# 1.6680930243601892
# 1.6680930166604382
# 1.5580828071705048
# 0.31897368923791736
# 1.3970614060707978
# 1.6699563681302643
# 1.6699563712428258
# 1.6680968740703443
# 1.670340417984256
# 1.6703404180445602
# 1.6699777962162539
# 1.6703381385638485
# 1.6703405603313204
# 1.6703405603313612
# 1.6703404183737245
# 1.6703405603313204
# 1.6703405603313204
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 19
#     # data points      = 6
#     # variables        = 1
#     chi-square         = 112.475705
#     reduced chi-square = 22.4951410
#     Akaike info crit   = 19.5858667
#     Bayesian info crit = 19.3776261
# [[Variables]]
#     k0:  0.33952991 +/- 941358.043 (277253347.08%) (init = 0.01)
# Eacts [-1230.1268901521134]
# Pre factors [0.4914981979453985]
# 6.862553030713592
# 6.862553030713592
# 6.862553030713592
# 6.862575983446471
# 6.862552950360725
# 6.862553030713592
# 6.862553030713592
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 3
#     # data points      = 12
#     # variables        = 2
#     chi-square         = 27648
#     reduced chi-square = 2764.80000
#     Akaike info crit   = 96.9088243
#     Bayesian info crit = 97.8786376
# ##  Warning: uncertainties could not be estimated:
#     A1:  at initial value
#     E1:  at initial value
# [[Variables]]
#     A1:  0.49149820 (init = 0.4914982)
#     E1:  1230.12689 (init = 1230.127)

# %%
#now to exhibit all different types of fitting
test_fit_1.fit_one(0,0) #this is the function to fit a single system to a single dataset, first argumet is the dataset that is fit
#in this dataset 0 (first initial condition, first temperature), and the second argument is the system of ODE's, this is 0 since we only have one system
# Out:
# 1.0219462565018236
# 1.0219462565018236
# 1.0219462565018236
# 1.0219462858679005
# -9.24593553749302
# 0.26700111852357133
# 1.0316681482281185
# 1.0316681311147002
# 1.045608920808541
# 1.0456089223417124
# 1.0315148408034105
# 1.0456792258119987
# 1.0456792251446725
# 1.0456089135257502
# 1.0456962162180417
# 1.0456962162140546
# 1.0456795147105473
# 1.04569606779637
# 1.0456962162180417
# 1.0456962162180417
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 16
#     # data points      = 6
#     # variables        = 1
#     chi-square         = 147.270756
#     reduced chi-square = 29.4541512
#     Akaike info crit   = 21.2030798
#     Bayesian info crit = 20.9948393
# [[Variables]]
#     k0:  0.01382407 +/- 1290.56549 (9335637.38%) (init = 0.01)

# %%
#fit many is for fittin many datasets with the same system at once, the first argument is now a list of all datasets you want to fit
test_fit_1.fit_many_entries([0,1],0) #try it out, there ar 4 datasets so [0:] also works for example
# Out:
# 1.0219462565018236
# 1.0219462565018236
# 1.0219462565018236
# 1.0219462858679005
# -9.24593553749302
# 0.26700111852357133
# 1.0316681482281185
# 1.0316681311147002
# 1.045608920808541
# 1.0456089223417124
# 1.0315148408034105
# 1.0456792258119987
# 1.0456792251446725
# 1.0456089135257502
# 1.0456962162180417
# 1.0456962162140546
# 1.0456795147105473
# 1.04569606779637
# 1.0456962162180417
# 1.0456962162180417
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 16
#     # data points      = 6
#     # variables        = 1
#     chi-square         = 147.270756
#     reduced chi-square = 29.4541512
#     Akaike info crit   = 21.2030798
#     Bayesian info crit = 20.9948393
# [[Variables]]
#     k0:  0.01382407 +/- 1290.56549 (9335637.38%) (init = 0.01)
# 0.9429787619491717
# 0.9429787619491717
# 0.9429787619491717
# 0.9429789351572483
# -3.775612895434099
# 1.4696144358717718
# 1.4696144401551783
# 1.066580903148691
# 1.467891276441173
# 1.4700682697231187
# 1.470068269706433
# 1.4696142528694178
# 1.4700640587260572
# 1.470068259685728
# 1.4700682697231187
# 1.4700682697231187
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 12
#     # data points      = 6
#     # variables        = 1
#     chi-square         = 123.121689
#     reduced chi-square = 24.6243378
#     Akaike info crit   = 20.1284824
#     Bayesian info crit = 19.9202419
# [[Variables]]
#     k0:  0.02700418 +/- 363.819399 (1347270.58%) (init = 0.01)

# %%
#now for an exmple that takes multiple constants and systems of ODE's into account
ks_2 = [0.01209668296564242, 0.012690318715024702] #now we have 2 constants

concs_2 = [1,0,0,1,0]# all have the same starting conditions



reactions_2 = {1:["ks[0]*concs[0]"],
               2:["ks[1]*concs[3]"]}#there are 2 reactions now, one is substrate depleteion, the second is catalyst death

matrix_2 = {"dEdt": {1:-1},
          "dA1dt": {1:1},
          "dA2dt": {1:1},
         "dprecatdt": {2:-1},
         "ddeadcatdt": {2:1}} #all the species, and teh reactions they participate in

to_run_2 = [{1:1,2:1},{1:1}] #now comes the part where we make 2 systems, one is with catalyst death , so it inludes reaction 1 and 2,
#the second is without catalyst dath, so it only includes the first reactions, the reason this is a dictionary is shown in test_6 below

# %%
test_2 = prg.ODE_systems(reactions_2,matrix_2,ks_2,concs_2,to_run_2) #make ODE systems out of it, if to run is included it automatically
#detects how many systems there are, and makes them.

# %%
#Here we now see that th first system is with catalyst death, and the second system is without
# for the second system the unneeded second reaction constant is set to 0, and unneeded concentrations are automatically dropped.
prof_2 = test_2.run_ODEs()
test_2.get_matrices()
# Out:
#  reaction matrix: {'dEdt': {1: -1}, 'dA1dt': {1: 1}, 'dA2dt': {1: 1}, 'dprecatdt': {2: -1}, 'ddeadcatdt': {2: 1}}
#  rate constants: [0.01209668296564242, 0.012690318715024702]
#  reactions: {1: 'ks[0]*concs[0]', 2: 'ks[1]*concs[3]'}
#  initial conditions: [1, 0, 0, 1, 0]
#  number of constants: 2
#  reaction matrix: {'dEdt': {1: -1}, 'dA1dt': {1: 1}, 'dA2dt': {1: 1}}
#  rate constants: [0.01209668296564242, 0]
#  reactions: {1: 'ks[0]*concs[0]'}
#  initial conditions: [1, 0, 0]
#  number of constants: 2
# [[{'dEdt': {1: -1},
#    'dA1dt': {1: 1},
#    'dA2dt': {1: 1},
#    'dprecatdt': {2: -1},
#    'ddeadcatdt': {2: 1}},
#   [0.01209668296564242, 0.012690318715024702],
#   {1: 'ks[0]*concs[0]', 2: 'ks[1]*concs[3]'},
#   [1, 0, 0, 1, 0],
#   2],
#  [{'dEdt': {1: -1}, 'dA1dt': {1: 1}, 'dA2dt': {1: 1}},
#   [0.01209668296564242, 0],
#   {1: 'ks[0]*concs[0]'},
#   [1, 0, 0],
#   2]]

# %%
#and again some examples of fitting
test_fit_2 = prg.fit_data(data, test_2.get_matrices())
test_fit_2.fit_full(0)
# Out:
#  reaction matrix: {'dEdt': {1: -1}, 'dA1dt': {1: 1}, 'dA2dt': {1: 1}, 'dprecatdt': {2: -1}, 'ddeadcatdt': {2: 1}}
#  rate constants: [0.01209668296564242, 0.012690318715024702]
#  reactions: {1: 'ks[0]*concs[0]', 2: 'ks[1]*concs[3]'}
#  initial conditions: [1, 0, 0, 1, 0]
#  number of constants: 2
#  reaction matrix: {'dEdt': {1: -1}, 'dA1dt': {1: 1}, 'dA2dt': {1: 1}}
#  rate constants: [0.01209668296564242, 0]
#  reactions: {1: 'ks[0]*concs[0]'}
#  initial conditions: [1, 0, 0]
#  number of constants: 2
# 2.7330082395730484
# 2.7330082395730484
# 2.7330082395730484
# 2.733008326736157
# 2.7330082395730484
# -430.19458424645705
# -24.06668702934931
# 2.591651846368773
# 2.760283231118593
# 2.7602832399615114
# 2.760283231118593
# 2.7429056216478127
# 2.760568858690581
# 2.7605688587254136
# 2.760568858690581
# 2.760287430552527
# 2.7605662479280353
# 2.7605688528116614
# 2.760568858690581
# 2.760568858690581
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 16
#     # data points      = 6
#     # variables        = 2
#     chi-square         = 1783.18792
#     reduced chi-square = 445.796979
#     Akaike info crit   = 38.1663912
#     Bayesian info crit = 37.7499102
# ##  Warning: uncertainties could not be estimated:
#     k1:  at initial value
# [[Variables]]
#     k0:  0.01132154 (init = 0.01)
#     k1:  0.01000000 (init = 0.01)
# 2.0189148419613794
# 2.0189148419613794
# 2.0189148419613794
# 2.018915208334892
# 2.0189148419613794
# -46.43753603569201
# 2.9688356154330138
# 2.9688356396578888
# 2.9688356154330138
# 2.3184553213759767
# 2.9736159314813957
# 2.9736159253942356
# 2.9736159314813957
# 2.9688284061668684
# 2.9739446252032424
# 2.9739446251968116
# 2.9739446252032424
# 2.973617007702216
# 2.9739414119075187
# 2.9739445992778
# 2.9739446252032424
# 2.9739446252032424
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 18
#     # data points      = 6
#     # variables        = 2
#     chi-square         = 1739.31937
#     reduced chi-square = 434.829842
#     Akaike info crit   = 38.0169381
#     Bayesian info crit = 37.6004570
# ##  Warning: uncertainties could not be estimated:
#     k1:  at initial value
# [[Variables]]
#     k0:  0.02361256 (init = 0.01)
#     k1:  0.01000000 (init = 0.01)
# Eacts [-7333.660589611362, 7.322217024764171e-12]
# Pre factors [0.21421774782582167, 0.009999999999999969]
# 17.68104133823252
# 17.68104133823252
# 17.68104133823252
# 17.681056961584396
# 17.68104133823252
# 17.681041207241208
# 17.68104133823252
# 17.68104133823252
# 17.68104133823252
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5
#     # data points      = 12
#     # variables        = 4
#     chi-square         = 307200
#     reduced chi-square = 38400.0000
#     Akaike info crit   = 129.804172
#     Bayesian info crit = 131.743798
# ##  Warning: uncertainties could not be estimated:
#     A1:  at initial value
#     A2:  at initial value
#     E1:  at initial value
#     E2:  at initial value
#     E2:  at boundary
# [[Variables]]
#     A1:  0.21421775 (init = 0.2142177)
#     A2:  0.01000000 (init = 0.01)
#     E1:  7333.66059 (init = 7333.661)
#     E2:  1000.00000 (init = 1000)

# %%
test_fit_2 = prg.fit_data(data, test_2.get_matrices())
test_fit_2.fit_one(0,1)
# Out:
#  reaction matrix: {'dEdt': {1: -1}, 'dA1dt': {1: 1}, 'dA2dt': {1: 1}, 'dprecatdt': {2: -1}, 'ddeadcatdt': {2: 1}}
#  rate constants: [0.01209668296564242, 0.012690318715024702]
#  reactions: {1: 'ks[0]*concs[0]', 2: 'ks[1]*concs[3]'}
#  initial conditions: [1, 0, 0, 1, 0]
#  number of constants: 2
#  reaction matrix: {'dEdt': {1: -1}, 'dA1dt': {1: 1}, 'dA2dt': {1: 1}}
#  rate constants: [0.01209668296564242, 0]
#  reactions: {1: 'ks[0]*concs[0]'}
#  initial conditions: [1, 0, 0]
#  number of constants: 2
# 1.0219462565018236
# 1.0219462565018236
# 1.0219462565018236
# 1.0219462858679005
# 1.0219462565018236
# -9.24593553749302
# 0.26700111852357933
# 1.0261501565171531
# 1.0261501367330848
# 1.0261501565171531
# 1.045488378617417
# 1.0454883763075111
# 1.045488378617417
# 1.029754080398942
# 1.0456950799102294
# 1.045695079737055
# 1.0456950799102294
# 1.0455416276081184
# 1.0456961400433742
# 1.0456961400884284
# 1.0456961400433742
# 1.0456950799090046
# 1.0456962168174793
# 1.0456962168174793
# 1.0456962168174793
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 6
#     # variables        = 2
#     chi-square         = 147.270756
#     reduced chi-square = 36.8176890
#     Akaike info crit   = 23.2030798
#     Bayesian info crit = 22.7865987
# ##  Warning: uncertainties could not be estimated:
#     k1:  at initial value
# [[Variables]]
#     k0:  0.01382338 (init = 0.01)
#     k1:  0.01000000 (init = 0.01)

# %%
test_fit_2.fit_many_systems(1,[0,1])
# Out:
# 0.9217432625846216
# 0.9217432625846216
# 0.9217432625846216
# 0.9217434230023887
# 0.9217432625846216
# -15.93757778201511
# 1.4055314045245435
# 1.4055314090515971
# 1.4055314045245435
# 1.0557497472447623
# 1.404504142303837
# 1.406105568584719
# 1.4061055685683828
# 1.406105568584719
# 1.4055312500422432
# 1.4061002169515997
# 1.4061055527029651
# 1.406105568584719
# 1.406105568584719
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 15
#     # data points      = 6
#     # variables        = 2
#     chi-square         = 443.130129
#     reduced chi-square = 110.782532
#     Akaike info crit   = 29.8126240
#     Bayesian info crit = 29.3961430
# ##  Warning: uncertainties could not be estimated:
#     k1:  at initial value
# [[Variables]]
#     k0:  0.02717128 (init = 0.01)
#     k1:  0.01000000 (init = 0.01)
# 0.9217432625846216
# 0.9217432625846216
# 0.9217432625846216
# 0.9217434230023887
# 0.9217432625846216
# -3.7758159620897795
# 1.4050047421999738
# 1.4050047360313953
# 1.4050047421999738
# 0.9323980791620958
# 1.4047697997110653
# 1.406105572131246
# 1.4061055721193285
# 1.406105572131246
# 1.4050031846884634
# 1.406094968100269
# 1.406105504047784
# 1.406105572131246
# 1.406105572131246
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 15
#     # data points      = 6
#     # variables        = 2
#     chi-square         = 126.623196
#     reduced chi-square = 31.6557990
#     Akaike info crit   = 22.2967375
#     Bayesian info crit = 21.8802564
# ##  Warning: uncertainties could not be estimated:
#     k1:  at initial value
# [[Variables]]
#     k0:  0.02717053 (init = 0.01)
#     k1:  0.01000000 (init = 0.01)

# %%
test_fit_2.fit_many([0,1],[0,1])
# Out:
# 1.0529095320631705
# 1.0529095320631705
# 1.0529095320631705
# 1.0529095749896722
# 1.0529095320631705
# -9.662806500947843
# -1.6721451423693952
# 1.0431077894730798
# 1.1031793040248787
# 1.1031793005262824
# 1.1031793040248787
# 1.0548254187234312
# 1.1037067033186774
# 1.1037067032670909
# 1.1037067033186774
# 1.1031937251434432
# 1.103703009237448
# 1.1037068136371095
# 1.1037068136371095
# 1.1037068136371095
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 16
#     # data points      = 6
#     # variables        = 2
#     chi-square         = 474.864195
#     reduced chi-square = 118.716049
#     Akaike info crit   = 30.2276163
#     Bayesian info crit = 29.8111353
# ##  Warning: uncertainties could not be estimated:
#     k1:  at initial value
# [[Variables]]
#     k0:  0.01591924 (init = 0.01)
#     k1:  0.01000000 (init = 0.01)
# 1.0529095320631705
# 1.0529095320631705
# 1.0529095320631705
# 1.0529095749896722
# 1.0529095320631705
# -15.797435324284832
# 0.7404944691984352
# 1.0952683033313222
# 1.0952682900970352
# 1.0952683033313222
# 1.0646971467474315
# 1.1036338684860274
# 1.1036338671690604
# 1.1036338684860274
# 1.0973383689381329
# 1.103706809679668
# 1.1037068096894371
# 1.103706809679668
# 1.103633864132774
# 1.1037061740876977
# 1.1037068130908376
# 1.1037068130908376
# 1.1037068130908376
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 19
#     # data points      = 6
#     # variables        = 2
#     chi-square         = 143.842122
#     reduced chi-square = 35.9605305
#     Akaike info crit   = 23.0617411
#     Bayesian info crit = 22.6452601
# ##  Warning: uncertainties could not be estimated:
#     k1:  at initial value
# [[Variables]]
#     k0:  0.01591997 (init = 0.01)
#     k1:  0.01000000 (init = 0.01)
# 0.9217432625846216
# 0.9217432625846216
# 0.9217432625846216
# 0.9217434230023887
# 0.9217432625846216
# -15.93757778201511
# 1.4055314045245435
# 1.4055314090515971
# 1.4055314045245435
# 1.0557497472447623
# 1.404504142303837
# 1.406105568584719
# 1.4061055685683828
# 1.406105568584719
# 1.4055312500422432
# 1.4061002169515997
# 1.4061055527029651
# 1.406105568584719
# 1.406105568584719
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 15
#     # data points      = 6
#     # variables        = 2
#     chi-square         = 443.130129
#     reduced chi-square = 110.782532
#     Akaike info crit   = 29.8126240
#     Bayesian info crit = 29.3961430
# ##  Warning: uncertainties could not be estimated:
#     k1:  at initial value
# [[Variables]]
#     k0:  0.02717128 (init = 0.01)
#     k1:  0.01000000 (init = 0.01)
# 0.9217432625846216
# 0.9217432625846216
# 0.9217432625846216
# 0.9217434230023887
# 0.9217432625846216
# -3.7758159620897795
# 1.4050047421999738
# 1.4050047360313953
# 1.4050047421999738
# 0.9323980791620958
# 1.4047697997110653
# 1.406105572131246
# 1.4061055721193285
# 1.406105572131246
# 1.4050031846884634
# 1.406094968100269
# 1.406105504047784
# 1.406105572131246
# 1.406105572131246
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 15
#     # data points      = 6
#     # variables        = 2
#     chi-square         = 126.623196
#     reduced chi-square = 31.6557990
#     Akaike info crit   = 22.2967375
#     Bayesian info crit = 21.8802564
# ##  Warning: uncertainties could not be estimated:
#     k1:  at initial value
# [[Variables]]
#     k0:  0.02717053 (init = 0.01)
#     k1:  0.01000000 (init = 0.01)

# %%
#now for a highly complex system example
ks_6 = [0.01209668296564242, 0.01517495478255645, 0.0042608145032644508, 0.0897487647678990227, 0.032891811706016034, 0.012690318715024702]
concs_6 = [1,0,0,0,1,0,0]

reactions_6 = {1: ["ks[0]*concs[0]*concs[4]","ks[0]*concs[0]"], #note that we now define that reaction 1 can have 2 different options
               2: ["ks[1]*concs[0]*concs[1]"],
               3: ["ks[2]*concs[2]*concs[3]"],
               4 : ["ks[3]*concs[3]*concs[4]"],
               5: ["ks[4]*concs[5]*CH2"],
               6: ["ks[5]*concs[4]"]}

matrix_6 = {"dEdt": {1:-1, 2:-1, 3:1}, #example of how a more complex matrix looks
          "dA1dt": {1:1, 2:-1, 3:1, 4:2},
          "dA2dt": {1:1, 2:1, 3:-1},
            "dtEdt": {2:1, 3:-1, 4:-1},
         "dprecatdt": {1:-1, 4:-1, 5:1, 6:-1},
         "dcatdt": {1:1, 4:1, 5:-1},
           "dcatdeaddt": {6:1}}

to_run_6 = [{1:1,2:1,3:1,4:1,5:1,6:1},{1:1,2:1,3:1,5:1,6:1},{1:2,2:1,3:1,4:1,5:1,6:1}] #the last entry explains why this is a dictionary
#if a researcher wants to simultaneously runs systems with different reactions they can be selected per system in the to_run parameter dictionaries

# %%
test_6 = prg.ODE_systems(reactions_6,matrix_6,ks_6,concs_6,to_run = to_run_6)

# %%
#and again we fit everything
prof_6 = test_6.run_ODEs()
test_6.get_matrices()
# Out:
#  reaction matrix: {'dEdt': {1: -1, 2: -1, 3: 1}, 'dA1dt': {1: 1, 2: -1, 3: 1, 4: 2}, 'dA2dt': {1: 1, 2: 1, 3: -1}, 'dtEdt': {2: 1, 3: -1, 4: -1}, 'dprecatdt': {1: -1, 4: -1, 5: 1, 6: -1}, 'dcatdt': {1: 1, 4: 1, 5: -1}, 'dcatdeaddt': {6: 1}}
#  rate constants: [0.01209668296564242, 0.01517495478255645, 0.004260814503264451, 0.08974876476789902, 0.03289181170601604, 0.012690318715024702]
#  reactions: {1: 'ks[0]*concs[0]*concs[4]', 2: 'ks[1]*concs[0]*concs[1]', 3: 'ks[2]*concs[2]*concs[3]', 4: 'ks[3]*concs[3]*concs[4]', 5: 'ks[4]*concs[5]*CH2', 6: 'ks[5]*concs[4]'}
#  initial conditions: [1, 0, 0, 0, 1, 0, 0]
#  number of constants: 6
#  reaction matrix: {'dEdt': {1: -1, 2: -1, 3: 1}, 'dA1dt': {1: 1, 2: -1, 3: 1}, 'dA2dt': {1: 1, 2: 1, 3: -1}, 'dtEdt': {2: 1, 3: -1}, 'dprecatdt': {1: -1, 5: 1, 6: -1}, 'dcatdt': {1: 1, 5: -1}, 'dcatdeaddt': {6: 1}}
#  rate constants: [0.01209668296564242, 0.01517495478255645, 0.004260814503264451, 0, 0.03289181170601604, 0.012690318715024702]
#  reactions: {1: 'ks[0]*concs[0]*concs[4]', 2: 'ks[1]*concs[0]*concs[1]', 3: 'ks[2]*concs[2]*concs[3]', 5: 'ks[4]*concs[5]*CH2', 6: 'ks[5]*concs[4]'}
#  initial conditions: [1, 0, 0, 0, 1, 0, 0]
#  number of constants: 6
#  reaction matrix: {'dEdt': {1: -1, 2: -1, 3: 1}, 'dA1dt': {1: 1, 2: -1, 3: 1, 4: 2}, 'dA2dt': {1: 1, 2: 1, 3: -1}, 'dtEdt': {2: 1, 3: -1, 4: -1}, 'dprecatdt': {1: -1, 4: -1, 5: 1, 6: -1}, 'dcatdt': {1: 1, 4: 1, 5: -1}, 'dcatdeaddt': {6: 1}}
#  rate constants: [0.01209668296564242, 0.01517495478255645, 0.004260814503264451, 0.08974876476789902, 0.03289181170601604, 0.012690318715024702]
#  reactions: {1: 'ks[0]*concs[0]', 2: 'ks[1]*concs[0]*concs[1]', 3: 'ks[2]*concs[2]*concs[3]', 4: 'ks[3]*concs[3]*concs[4]', 5: 'ks[4]*concs[5]*CH2', 6: 'ks[5]*concs[4]'}
#  initial conditions: [1, 0, 0, 0, 1, 0, 0]
#  number of constants: 6
# [[{'dEdt': {1: -1, 2: -1, 3: 1},
#    'dA1dt': {1: 1, 2: -1, 3: 1, 4: 2},
#    'dA2dt': {1: 1, 2: 1, 3: -1},
#    'dtEdt': {2: 1, 3: -1, 4: -1},
#    'dprecatdt': {1: -1, 4: -1, 5: 1, 6: -1},
#    'dcatdt': {1: 1, 4: 1, 5: -1},
#    'dcatdeaddt': {6: 1}},
#   [0.01209668296564242,
#    0.01517495478255645,
#    0.004260814503264451,
#    0.08974876476789902,
#    0.03289181170601604,
#    0.012690318715024702],
#   {1: 'ks[0]*concs[0]*concs[4]',
#    2: 'ks[1]*concs[0]*concs[1]',
#    3: 'ks[2]*concs[2]*concs[3]',
#    4: 'ks[3]*concs[3]*concs[4]',
#    5: 'ks[4]*concs[5]*CH2',
#    6: 'ks[5]*concs[4]'},
#   [1, 0, 0, 0, 1, 0, 0],
#   6],
#  [{'dEdt': {1: -1, 2: -1, 3: 1},
#    'dA1dt': {1: 1, 2: -1, 3: 1},
#    'dA2dt': {1: 1, 2: 1, 3: -1},
#    'dtEdt': {2: 1, 3: -1},
#    'dprecatdt': {1: -1, 5: 1, 6: -1},
#    'dcatdt': {1: 1, 5: -1},
#    'dcatdeaddt': {6: 1}},
#   [0.01209668296564242,
#    0.01517495478255645,
#    0.004260814503264451,
#    0,
#    0.03289181170601604,
#    0.012690318715024702],
#   {1: 'ks[0]*concs[0]*concs[4]',
#    2: 'ks[1]*concs[0]*concs[1]',
#    3: 'ks[2]*concs[2]*concs[3]',
#    5: 'ks[4]*concs[5]*CH2',
#    6: 'ks[5]*concs[4]'},
#   [1, 0, 0, 0, 1, 0, 0],
#   6],
#  [{'dEdt': {1: -1, 2: -1, 3: 1},
#    'dA1dt': {1: 1, 2: -1, 3: 1, 4: 2},
#    'dA2dt': {1: 1, 2: 1, 3: -1},
#    'dtEdt': {2: 1, 3: -1, 4: -1},
#    'dprecatdt': {1: -1, 4: -1, 5: 1, 6: -1},
#    'dcatdt': {1: 1, 4: 1, 5: -1},
#    'dcatdeaddt': {6: 1}},
#   [0.01209668296564242,
#    0.01517495478255645,
#    0.004260814503264451,
#    0.08974876476789902,
#    0.03289181170601604,
#    0.012690318715024702],
#   {1: 'ks[0]*concs[0]',
#    2: 'ks[1]*concs[0]*concs[1]',
#    3: 'ks[2]*concs[2]*concs[3]',
#    4: 'ks[3]*concs[3]*concs[4]',
#    5: 'ks[4]*concs[5]*CH2',
#    6: 'ks[5]*concs[4]'},
#   [1, 0, 0, 0, 1, 0, 0],
#   6]]

# %%
test_fit_6 = prg.fit_data(data, test_6.get_matrices())
test_fit_6.fit_one(0,1,iterations = 40) #you can set the amount of iterations
# Out:
# 0.6531056790777557
# 0.6531056790777557
# 0.6531056790777557
# 0.6531058132455381
# 0.6531057077590473
# 0.6531056551007766
# 0.6531056790777557
# 0.6531056857065933
# 0.6531055973369493
# -4.331058989538107
# 0.5385544247984323
# 0.7542845168538641
# 0.7542844691723856
# 0.7542845153177363
# 0.7542845080591098
# 0.7542845168538641
# 0.7542845179033858
# 0.7542845015290061
# 0.8038809023867362
# 0.8038810060281399
# 0.8038809039227108
# 0.8038809048660784
# 0.8038809023867362
# 0.8038809004812368
# 0.803881008200922
# 1.0554894906138848
# 1.055489471852317
# 1.0554894891561728
# 1.0554894880228396
# 1.0554894906138848
# 1.0554894912795652
# 1.055489484999168
# 1.0002272987457737
# 1.090309669921389
# 1.0903096685009632
# 1.090309668817
# 1.0903096684632698
# 1.090309669921389
# 1.09030967001753
# 1.090309669011353
# 1.1056653065713693
# 1.1056653163495382
# 1.1056653054682086
# 1.1056653054682086
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 40
#     # data points      = 6
#     # variables        = 6
#     chi-square         = 997.583203
#     reduced chi-square = 997.583203
#     Akaike info crit   = 42.6814565
#     Bayesian info crit = 41.4320133
# ##  Warning: uncertainties could not be estimated:
#     k3:  at initial value
# [[Variables]]
#     k0:  0.01745025 (init = 0.01)
#     k1:  0.08508721 (init = 0.01)
#     k2:  0.46801983 (init = 0.01)
#     k3:  0.01000000 (init = 0.01)
#     k4:  0.36985668 (init = 0.01)
#     k5:  0.00333931 (init = 0.01)

# %%
test_fit_6.fit_full(0, iterations = 40, iterations_full = 100)
# Out:
# 1.5630242033375157
# 1.5630242033375157
# 1.5630242033375157
# 1.5630241372062836
# 1.5630241486046201
# 1.5630242353929975
# 1.5630242477442056
# 1.5630242358300597
# 1.5630239948500368
# -4.601020774321515
# -212.64215370859444
# -1.9237880348713667
# 1.8701015709446014
# 1.870101804630428
# 1.870101550260907
# 1.870101576426873
# 1.8701016092572431
# 1.8701016021369
# 1.8701013278777892
# 2.22911704874287
# 2.229117119853747
# 2.229117049148926
# 2.229117048463677
# 2.229117074573116
# 2.229117073356623
# 2.2291168585530516
# 2.584796843048869
# 2.584796702299128
# 2.5847968538403405
# 2.5847968406594437
# 2.5847968533092147
# 2.584796850305712
# 2.584796770732418
# 2.7560914924136863
# 2.756091586356678
# 2.75609150162787
# 2.756091489795561
# 2.7560915049349926
# 2.7560914960366008
# 2.756091433664407
# 2.7401697992803675
# 2.817767345693182
# 2.817767291025481
# 2.817767291025481
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 40
#     # data points      = 6
#     # variables        = 6
#     chi-square         = 3804.86907
#     reduced chi-square = 3804.86907
#     Akaike info crit   = 50.7136643
#     Bayesian info crit = 49.4642212
# ##  Warning: uncertainties could not be estimated:
# [[Variables]]
#     k0:  0.00727390 (init = 0.01)
#     k1:  0.01074421 (init = 0.01)
#     k2:  0.01311661 (init = 0.01)
#     k3:  0.06187065 (init = 0.01)
#     k4:  0.09546079 (init = 0.01)
#     k5:  0.00490182 (init = 0.01)
# 1.2561027288359004
# 1.2561027288359004
# 1.2561027288359004
# 1.2561031559167803
# 1.2561026696367055
# 1.2561027597365602
# 1.2561027804427838
# 1.256102765854108
# 1.2561024633409033
# -1.6349061878567135
# -1.0281000112200118
# 2.8695071158067345
# 2.869507010495557
# 2.869507129295277
# 2.869507116017757
# 2.869507113108482
# 2.8695071155430805
# 2.8695071222232604
# 2.698325690025249
# 2.99806697794782
# 2.998066982099373
# 2.9980669751547895
# 2.9980669779447258
# 2.998066978333125
# 2.998066978057163
# 2.9980669760959153
# 2.9007543272974434
# 3.001101516471148
# 3.0011015107172083
# 3.0011015153995446
# 3.00110151647688
# 3.001101516595237
# 3.00110151652582
# 3.0011015158085685
# 3.002515469484428
# 3.0025154698177117
# 3.002515469168557
# 3.002515469492914
# 3.0025154695774843
# 3.0025154695200427
# 3.0025154690636437
# 3.002087555078125
# 3.002631064428904
# 3.002631064428904
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 40
#     # data points      = 6
#     # variables        = 6
#     chi-square         = 3749.21072
#     reduced chi-square = 3749.21072
#     Akaike info crit   = 50.6252469
#     Bayesian info crit = 49.3758037
# ##  Warning: uncertainties could not be estimated:
# [[Variables]]
#     k0:  0.01553693 (init = 0.01)
#     k1:  0.02768315 (init = 0.01)
#     k2:  0.44641941 (init = 0.01)
#     k3:  0.15906190 (init = 0.01)
#     k4:  0.30889718 (init = 0.01)
#     k5:  0.00108590 (init = 0.01)
# Eacts [-7571.66702757976, -9442.61703698402, -35191.95996710012, -9420.568107114586, -11715.684986903254, 15037.016564229325]
# Pre factors [0.15141164092838882, 0.47352114085709573, 17599.788601752527, 2.7027791153734184, 10.465998425411389, 1.180554525718719e-05]
# 16.747924727564808
# 16.747924727564808
# 16.747924727564808
# 16.747957762986942
# 16.747925190574897
# 16.747924726522612
# 16.747925720004517
# 16.74792492885611
# 16.747924312023862
# 16.747924511627588
# 16.747924726531878
# 16.747924730378685
# 16.74792469715574
# 16.74792471584766
# 16.7479247275648
# 16.747924727564808
# 16.747924727564808
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 13
#     # data points      = 12
#     # variables        = 12
#     chi-square         = 602112
#     reduced chi-square = 602112.000
#     Akaike info crit   = 153.879505
#     Bayesian info crit = 159.698385
# ##  Warning: uncertainties could not be estimated:
#     A1:  at initial value
#     A2:  at initial value
#     A3:  at initial value
#     A4:  at initial value
#     A5:  at initial value
#     A6:  at initial value
#     E1:  at initial value
#     E2:  at initial value
#     E3:  at initial value
#     E4:  at initial value
#     E5:  at initial value
#     E6:  at initial value
#     E6:  at boundary
# [[Variables]]
#     A1:  0.15141164 (init = 0.1514116)
#     A2:  0.47352114 (init = 0.4735211)
#     A3:  17599.7886 (init = 17599.79)
#     A4:  2.70277912 (init = 2.702779)
#     A5:  10.4659984 (init = 10.466)
#     A6:  1.1806e-05 (init = 1.180555e-05)
#     E1:  7571.66703 (init = 7571.667)
#     E2:  9442.61704 (init = 9442.617)
#     E3:  35191.9600 (init = 35191.96)
#     E4:  9420.56811 (init = 9420.568)
#     E5:  11715.6850 (init = 11715.68)
#     E6:  1000.00000 (init = 1000)
